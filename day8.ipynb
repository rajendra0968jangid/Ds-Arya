# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **What is Pandas?**
#
# Pandas is a Python library used for:
#
# 1. Reading data
# 2. Cleaning data
# 3. Analyzing data
# 4. Manipulating data

# %% [markdown]
# #create DataFrame
# 1. DataFrame for list 1d (pd series)
# 2. list -> indexing name (pd dataframe)
# 3. DataFrame for dict

# %%
import pandas as pd
df = pd.Series([10,20,30])
print(df)
print(df[0])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# 10

# %%
#dict
import pandas as pd
dict = {"name":["dheeraj","kunal","praveen","anjali","abhishek singh"],
        "age":[20,21,22,23,30],
        "salary":[15000,20000,25000,30000,35000]
        }
df = pd.DataFrame(dict)
print(df)
# Out:
#              name  age  salary
# 0         dheeraj   20   15000
# 1           kunal   21   20000
# 2         praveen   22   25000
# 3          anjali   23   30000
# 4  abhishek singh   30   35000

# %% [markdown]
# **Save and Load data from CSV,json,excel**
#
# 0. url = "https://raw.githubusercontent.com/rajendra0968jangid/machine_learning_demo/main/placement.csv"
# 1. csv import -> pd.read_csv("filename")
# 2. csv export -> df.to_csv('filename')
# 3. json import -> pd.read_json('filename')
# 4. json export -> df.to_json('filename')
# 5. excel import -> pd.read_excel('filename', sheet_name='Sheet1')
# 6. excel export -> df.to_excel('filename', index=False, sheet_name='Sheet1')

# %%
# csv
import pandas as pd
# method of github
# url = "https://raw.githubusercontent.com/rajendra0968jangid/Ds-Arya/main/file1.csv"
# method of google drive
from google.colab import drive
drive.mount('/content/drive')
url = '/content/drive/MyDrive/file1.csv'
# use csv file
df = pd.read_csv(url)
print(df)
# Out:
#        name  roll no
# 0   dheeraj      123
# 1     kunal     1234
# 2  abhishek    12345
# 3   praveen    12356
# 4    anjali  1234567

# %% [markdown]
# # Basic Dataframe Understanding
#
# 1. head()
# 2. tail()
# 3. shape
# 4. info()
# 5. rename
# 6. describe()-> count,mean,std,min,max

# %% [markdown]
# **Operation on Columns**
#
# 1. df["column name"] -> selecting column
# 2. df["column name"] = [values] -> add new column
# 3. df.drop("column name") -> delete column

# %% [markdown]
# **Operation on Rows**
# 1. print(df.loc[0,"Name"]) -> label based
# 2. print(df.iloc[1]) -> Index Based

# %% [markdown]
# **Filter DataFrame**
# 1. Filter DataFrame -> Ex. df[df["Age"] > 22]

# %% [markdown]
# **Sorting**
# 1. df.sort_values("column name")

# %%
# Working with Date Value

# %%
# Handling Missing Values

# %%
# Aggregation and Group By

# %%
# Concatenate and Merge DataFrame (JOINS)
