# %%
print("hello arya")
# Out:
# hello

# %% [markdown]
# **Environment Setup**
#
# 1.   Jupyter Notebook & VS Code Setup

# %% [markdown]
# **Python Fundamentals**

# %% [markdown]
# **Syntax, Variables & Data Types**

# %% [markdown]
# **int, float, str, bool**

# %% [markdown]
# **Type Conversion & Input/Output**

# %% [markdown]
# **Operators & Expressions**

# %% [markdown]
# **Conditional Statements**
#
# 1.    if, elif, else
