# %% [markdown]
# **Basic class and object**

# %% [markdown]
# **Constructor**

# %% [markdown]
# **Class method and self**

# %% [markdown]
# **Inheritance**

# %% [markdown]
# **Encapsulation**

# %% [markdown]
# **Poly morphism**

# %% [markdown]
# **Class variable**

# %% [markdown]
# **Tuples**

# %% [markdown]
# **Sets & Set Operations**

# %% [markdown]
# **File Handling**
